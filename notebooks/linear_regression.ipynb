# %% [markdown]
# # Code Generating a Model Using Linear Regression

# %% [markdown]
# Dependencies: numpy, pandas, sklearn

# %% [markdown]
# # Generates a model to find what the best thresholds are for each class

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib

# Reads data stored in the student_dropout.csv file which contains our pruned data set
raw_data = pd.read_csv('../data/student_dropout.csv')

# Sets up variables to hold the X, y and the names of columns for the variables in X
y = raw_data['Target']
raw_data = raw_data.drop(columns=['Target'])
column_names = raw_data.columns
X = raw_data.loc[:, column_names]

# Creates the train test split for the data using a 75:25 split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Normalizes our train and test variables
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Adds an extra column to the input variables to include the bias term
X_train_scaled = np.c_[np.ones((X_train_scaled.shape[0], 1)), X_train_scaled]
X_test_scaled = np.c_[np.ones((X_test_scaled.shape[0], 1)), X_test_scaled]

# Creates the Linear Regression model for the data
model = LinearRegression()
model.fit(X_train, y_train)

# Gets the predictions from our fitted model
y_pred = model.predict(X_test)

# Prints the coefficients
print(model.coef_)

# sets up variables to test which thresholds produce the best result
threshold = 0
thresh2 = 1
correct = 0
incorrect = 0

# Creates a loop that iterates 9 times and increments the lower threshold by 0.1
for j in range(9):
    threshold = threshold + 0.1
    thresh2 = 1
    # Creates a loop that iterates 9 times and increments the higher threshold by 0.1
    for k in range(9):
        thresh2 = thresh2 + 0.1
        correct = 0
        incorrect = 0
        # loops for every index in y_test and y_pred and checks if the prediction matches
        # the actual value with the given thresholds and tracks the number of correct and
        # incorrect predictions for the given thresholds
        for i, index in enumerate(y_test.index):
            if y_pred[i] > threshold and y_pred[i] < thresh2:
                if y_test[index] == 1:
                    correct = correct + 1
                else:
                    incorrect = incorrect + 1
            if y_pred[i] <= threshold:
                if y_test[index] == 0:
                    correct = correct + 1
                else:
                    incorrect = incorrect + 1
            if y_pred[i] >= thresh2:
                if y_test[index] == 2:
                    correct = correct + 1
                else:
                    incorrect = incorrect + 1
        print("With lower bound =", threshold)
        print("With higher bound =", thresh2)
        print("Correct:", correct)
        print("Incorrect:", incorrect)
        print()
# Out:
# [ 0.05246202  0.03337223 -0.08144331  0.40806127  0.02608489 -0.00657211
#  -0.00654232]
# With lower bound = 0.1
# With higher bound = 1.1
# Correct: 419
# Incorrect: 502
#
# With lower bound = 0.1
# With higher bound = 1.2000000000000002
# Correct: 515
# Incorrect: 406
#
# With lower bound = 0.1
# With higher bound = 1.3000000000000003
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.4000000000000004
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.5000000000000004
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.6000000000000005
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.7000000000000006
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.8000000000000007
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.1
# With higher bound = 1.9000000000000008
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.2
# With higher bound = 1.1
# Correct: 448
# Incorrect: 473
#
# With lower bound = 0.2
# With higher bound = 1.2000000000000002
# Correct: 544
# Incorrect: 377
#
# With lower bound = 0.2
# With higher bound = 1.3000000000000003
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.4000000000000004
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.5000000000000004
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.6000000000000005
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.7000000000000006
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.8000000000000007
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.2
# With higher bound = 1.9000000000000008
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.1
# Correct: 467
# Incorrect: 454
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.2000000000000002
# Correct: 563
# Incorrect: 358
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.3000000000000003
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.4000000000000004
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.5000000000000004
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.6000000000000005
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.7000000000000006
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.8000000000000007
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.30000000000000004
# With higher bound = 1.9000000000000008
# Correct: 570
# Incorrect: 351
#
# With lower bound = 0.4
# With higher bound = 1.1
# Correct: 481
# Incorrect: 440
#
# With lower bound = 0.4
# With higher bound = 1.2000000000000002
# Correct: 577
# Incorrect: 344
#
# With lower bound = 0.4
# With higher bound = 1.3000000000000003
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.4000000000000004
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.5000000000000004
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.6000000000000005
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.7000000000000006
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.8000000000000007
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.4
# With higher bound = 1.9000000000000008
# Correct: 584
# Incorrect: 337
#
# With lower bound = 0.5
# With higher bound = 1.1
# Correct: 499
# Incorrect: 422
#
# With lower bound = 0.5
# With higher bound = 1.2000000000000002
# Correct: 595
# Incorrect: 326
#
# With lower bound = 0.5
# With higher bound = 1.3000000000000003
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.4000000000000004
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.5000000000000004
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.6000000000000005
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.7000000000000006
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.8000000000000007
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.5
# With higher bound = 1.9000000000000008
# Correct: 602
# Incorrect: 319
#
# With lower bound = 0.6
# With higher bound = 1.1
# Correct: 522
# Incorrect: 399
#
# With lower bound = 0.6
# With higher bound = 1.2000000000000002
# Correct: 618
# Incorrect: 303
#
# With lower bound = 0.6
# With higher bound = 1.3000000000000003
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.4000000000000004
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.5000000000000004
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.6000000000000005
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.7000000000000006
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.8000000000000007
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.6
# With higher bound = 1.9000000000000008
# Correct: 625
# Incorrect: 296
#
# With lower bound = 0.7
# With higher bound = 1.1
# Correct: 535
# Incorrect: 386
#
# With lower bound = 0.7
# With higher bound = 1.2000000000000002
# Correct: 631
# Incorrect: 290
#
# With lower bound = 0.7
# With higher bound = 1.3000000000000003
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.4000000000000004
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.5000000000000004
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.6000000000000005
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.7000000000000006
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.8000000000000007
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7
# With higher bound = 1.9000000000000008
# Correct: 638
# Incorrect: 283
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.1
# Correct: 541
# Incorrect: 380
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.2000000000000002
# Correct: 637
# Incorrect: 284
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.3000000000000003
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.4000000000000004
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.5000000000000004
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.6000000000000005
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.7000000000000006
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.8000000000000007
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.7999999999999999
# With higher bound = 1.9000000000000008
# Correct: 644
# Incorrect: 277
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.1
# Correct: 551
# Incorrect: 370
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.2000000000000002
# Correct: 647
# Incorrect: 274
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.3000000000000003
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.4000000000000004
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.5000000000000004
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.6000000000000005
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.7000000000000006
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.8000000000000007
# Correct: 654
# Incorrect: 267
#
# With lower bound = 0.8999999999999999
# With higher bound = 1.9000000000000008
# Correct: 654
# Incorrect: 267

# %% [markdown]
# Best threshold is 0.9 and 1.5
#
# right = 654, wrong 267

# %% [markdown]
# # Final Linear Regression model using the optimal thresholds found in the previous code cell

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Reads data stored in the student_dropout.csv file which contains our pruned data set
raw_data = pd.read_csv('../data/student_dropout.csv')

# Sets up variables to hold the X, y and the names of columns for the variables in X
y = raw_data['Target']
raw_data = raw_data.drop(columns=['Target'])
column_names = raw_data.columns
X = raw_data.loc[:, column_names]

# Creates the train test split for the data using a 75:25 split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Normalizes our train and test variables
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Adds an extra column to the input variables to include the bias term
X_train_scaled = np.c_[np.ones((X_train_scaled.shape[0], 1)), X_train_scaled]
X_test_scaled = np.c_[np.ones((X_test_scaled.shape[0], 1)), X_test_scaled]

# Creates the Linear Regression model for the data
model = LinearRegression()
model.fit(X_train, y_train)

# Gets the predictions from our fitted model
y_pred = model.predict(X_test)

# Sets the best thresholds found from the preivous cell
thresh1 = 0.9
thresh2 = 1.5

# Loop that goes through every prediction and assigns the correct class based
# on the thresholds
for i in range(len(y_pred)):
    if y_pred[i] <= thresh1:
        y_pred[i] = 0
    elif y_pred[i] > thresh1 and y_pred[i] < thresh2:
        y_pred[i] = 1
    elif y_pred[i] > thresh2:
        y_pred[i] = 2

# Finds and prints the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy: {accuracy:.4f}")


# Save model and scaler
joblib.dump(model, '../models/linear_regression_model.pkl')
joblib.dump(scaler, '../models/linear_regression_scaler.pkl')
# Out:
# Accuracy: 0.7101
# ['models/linear_regression_scaler.pkl']
